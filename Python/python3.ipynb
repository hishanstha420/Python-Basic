# %% [markdown]
# # Classes

# %% [markdown]
# ## creating and Using class

# %%
#creating thre dog class
#dog.py
class Dog():#defined a class Dog, Capitalized names refer to classes in Python.
    """A simple attempt to model a dog."""
    
    def __init__(self,name,age):#A function that is part of class is method
        """Initialize name and age attributes."""
        self.name=name
        self.age=age
        
    def sit(self):
        """Simulate a dog sitting in response to a command."""
        print(self.name.title()+' is now sitting.')
        
    def roll_over(self):
        """Simulate a dog rolled over in response to a command."""
        print(self.name.title()+' just rolled over.')
#__init__() method is a special method puthon runs automatically whenever we create a new instance based on the class
#__init__() method has 3 parameters:self,name,age. The self parameter is required in method  and it most come before other parameters.
# __init__() method will automatically pass the self argument. Every method call associated with a class automatically passes self, 
        #which is a reference to the instance itself; it gives the individual instance access to the attributes and methods in the class. 
        # two variables self.name and self.age .Since it has prefix as self so it will be available to every method inside a class

# %% [markdown]
# ## Making Instances from class

# %%
my_dog=Dog('willie',8)
print('My dog name is '+my_dog.name.title()+'.')
print('My dog is '+str(my_dog.age)+' years old.')
# when python reads line 1 it automatically calsss the __init__() method in Dog with arguments 'willie' and 8.
#The __init__() method creates an instance representing this particular dog and sets name and age attribute using the value provided.
#The __init__() method has no explicit return statement, but Python automatically returns an instance representing this dog.

# %%
#Accessing Attributes
print(my_dog.name)
my_dog.age

# %%
#Calling Methods
my_dog=Dog('willie',8)
my_dog.sit()
my_dog.roll_over()

# %%
#Creating multiple instances
my_dog=Dog('Walker',5)
your_dog=Dog('lucy',6)
print('My dog name is '+my_dog.name.title()+'.')
print('My dog is '+str(my_dog.age)+' years old.')
my_dog.sit()
my_dog.roll_over()
print('\nMy dog name is '+your_dog.name.title()+'.')
print('My dog is '+str(your_dog.age)+' years old.')
your_dog.sit()
your_dog.roll_over()

# %%
#9.1 Resturants
class Resturant():
    
    def __init__(self,resturant_name,cuisine_type):
        self.resturant_name=resturant_name
        self.cuisine_type=cuisine_type
        
    def describe_resturant(self):
        print('Our resturant is '+self.resturant_name+' and it\'s famous for '+self.cuisine_type.title()+'.')
    
    def open_resturant(self):
        print(self.resturant_name+' is currently open.')

resturant=Resturant('KFC','chicken wings')
print('The name of resturant is '+resturant.resturant_name+'.')
print('The cuisine you ordered is '+resturant.cuisine_type.title()+'.')
resturant.describe_resturant()
resturant.open_resturant()

# %%
#9.2 Three resturants
resturant1=Resturant('Wendys','Burger')
resturant1.describe_resturant()
resturant2=Resturant('KFC','Chicken Wings')
resturant2.describe_resturant()
resturant3=Resturant('Kybi\'s Kitchen','Ramen')
resturant3.describe_resturant()

# %%
#9.3 Users
class User():
    def __init__(self,first_name,last_name,age,address):
        self.first_name=first_name
        self.last_name=last_name
        self.age=age
        self.address=address
        
    def describe_user(self):
        print("\nUser's name is "+self.first_name.title()+" "+self.last_name.title()+". S/he is "+str(self.age)+' years old and lives with family in '+self.address.title()+'.')
    def greet_user(self):
        print('Hello '+self.first_name.title()+'!')
user1=User('mandy','johnson',33,'sydney')
user1.describe_user()
user1.greet_user()
user2=User('hishan','shrestha',21,'kathmandu')
user2.describe_user()
user2.greet_user()

# %% [markdown]
# ## Working with class and Instances

# %%
#The car class
#car.py

class Car():
    def __init__(self,make,model,year):
        self.make=make
        self.model=model
        self.year=year
        
    def get_descriptive_name(self):
        long_name=str(self.year)+' '+self.make+' '+self.model
        return long_name.title()

my_new_car=Car('audi','a4',2016)
my_new_car.get_descriptive_name()

# %% [markdown]
# ### setting a default value for an attribute

# %%
class Car():
    def __init__(self,make,model,year):
        self.make=make
        self.model=model
        self.year=year
        self.odometer_reading=0
        
    def get_descriptive_name(self):
        long_name=str(self.year)+' '+self.make+' '+self.model
        return long_name.title()
    
    def read_odometer(self):
        print('This car has '+str(self.odometer_reading)+' miles on it.')

my_new_car=Car('audi','a4',2016)
print(my_new_car.get_descriptive_name()) 
my_new_car.read_odometer()

# %% [markdown]
# ### Modifying attribite value

# %%
#Modifying an attribute's value directly
print(my_new_car.get_descriptive_name()) 
my_new_car.odometer_reading=23
my_new_car.read_odometer()

# %%
#Modifying an Attribute’s Value Through a Method
class Car():
    def __init__(self,make,model,year):
        self.make=make
        self.model=model
        self.year=year
        self.odometer_reading=0
        
    def get_descriptive_name(self):
        long_name=str(self.year)+' '+self.make+' '+self.model
        return long_name.title()
    
    def update_odometer(self,milage):#new method
        """Set the odometer reading to the given value.
         Reject the change if it attempts to roll the odometer back.
         """
        if milage>=self.odometer_reading:
            self.odometer_reading=milage
        else:
            print('You cannot roll back an odometer!!\n')
            
    def read_odometer(self):
        print('This car has '+str(self.odometer_reading)+' miles on it.')
    
    
        

my_new_car=Car('audi','a4',2016)
print(my_new_car.get_descriptive_name())

my_new_car.update_odometer(26)
my_new_car.read_odometer()

my_new_car.update_odometer(23)
my_new_car.read_odometer()

# %%
#incrementing an attribute's value through a method
class Car():
    def __init__(self,make,model,year):
        self.make=make
        self.model=model
        self.year=year
        self.odometer_reading=0
        
    def get_descriptive_name(self):
        long_name=str(self.year)+' '+self.make+' '+self.model
        return long_name.title()
    
    def read_odometer(self):
        print('This car has '+str(self.odometer_reading)+' miles on it.')
    
    def update_odometer(self,milage):#new method
        """Set the odometer reading to the given value.
         Reject the change if it attempts to roll the odometer back.
         """
        if milage>=self.odometer_reading:
            self.odometer_reading=milage
        else:
            print('You cannot roll back an odometer!!\n')
            
    def increment_odometer(self,miles):
        self.odometer_reading+=miles
        

my_used_car=Car('subaru','outback',2016)
print(my_used_car.get_descriptive_name())

my_used_car.update_odometer(23500)
my_used_car.read_odometer()

my_used_car.increment_odometer(100)
my_used_car.read_odometer()

# %%
#9.4 Number Served
class Resturant():
    
    def __init__(self,resturant_name,cuisine_type):
        self.resturant_name=resturant_name
        self.cuisine_type=cuisine_type
        self.number_served=10
        
    def describe_resturant(self):
        print('Our resturant is '+self.resturant_name+' and it\'s famous for '+self.cuisine_type.title()+'.')
    
    def open_resturant(self):
        print(self.resturant_name+' is currently open.')
    
    def set_number_served(self,number):
        self.number_served=number
    
    def increment_number_served(self,num):
        self.number_served+=num

resturant=Resturant('KFC','chicken wings')
print('The number of customers served is '+str(resturant.number_served)+'.')

resturant.set_number_served(30)
print('\nThe number of customers served is '+str(resturant.number_served)+'.')

resturant.increment_number_served(100)
print('\nThe number of customers served is '+str(resturant.number_served)+'.')

# %%
#9.5 login attempts
class User():
    def __init__(self,first_name,last_name,age,address):
        self.first_name=first_name
        self.last_name=last_name
        self.age=age
        self.address=address
        self.login_attempts=0
        
    def describe_user(self):
        print("\nUser's name is "+self.first_name.title()+" "+self.last_name.title()+". S/he is "+str(self.age)+' years old and lives with family in '+self.address.title()+'.')
    
    def greet_user(self):
        print('Hello '+self.first_name.title()+'!')
        
    def increment_login_attempts(self):
        self.login_attempts+=1
    
    def reset_login_attempts(self):
        self.login_attempts=0
    
user1=User('mandy','johnson',33,'sydney')
user1.increment_login_attempts()
print(user1.login_attempts)
user1.increment_login_attempts()
print(user1.login_attempts)
user1.increment_login_attempts()
print(user1.login_attempts)
user1.increment_login_attempts()
print(user1.login_attempts)
user1.reset_login_attempts()
print(user1.login_attempts)

# %% [markdown]
# ## Inheritance

# %%
#The __init__() method for a child class
class Car():#parent class
    def __init__(self,make,model,year):
        self.make=make
        self.model=model
        self.year=year
        self.odometer_reading=0
        
    def get_descriptive_name(self):
        long_name=str(self.year)+' '+self.make+' '+self.model
        return long_name.title()
    
    def read_odometer(self):
        print('This car has '+str(self.odometer_reading)+' miles on it.')
    
    def update_odometer(self,milage):#new method
        """Set the odometer reading to the given value.
         Reject the change if it attempts to roll the odometer back.
         """
        if milage>=self.odometer_reading:
            self.odometer_reading=milage
        else:
            print('You cannot roll back an odometer!!\n')
            
    def increment_odometer(self,miles):
        self.odometer_reading+=miles
    
class ElectricCar(Car):#child class
    """Represent aspects of a car, specific to electric vehicles."""
    
    def __init__(self,make,model,year):
        """Initialize attributes of the parent class."""
        super().__init__(make,model,year)

my_tesla=ElectricCar('Tesla','model s',2016)
print(my_tesla.get_descriptive_name())

#The super() function at x is a special function that helps Python make connections between the parent and child class.

# %%
#Defining Attributes and Methods for the child class
class ElectricCar(Car):#child class 
    """Represent aspects of a car, specific to electric vehicles."""
    
    def __init__(self,make,model,year):
        """Initialize attributes of the parent class."""
        super().__init__(make,model,year)
        self.battery_percent=70
    
    def battery_percents(self):
        print('The battery percent of car is '+str(self.battery_percent)+'-kWh battery.')

my_tesla=ElectricCar('Tesla','model s',2016)
print(my_tesla.get_descriptive_name())
my_tesla.battery_percents()

# %%
#Overriding Methods from the Parent Class
class ElectricCar(Car):
    """Represent aspects of a car, specific to electric vehicles."""
    
    def __init__(self,make,model,year):
        """Initialize attributes of the parent class."""
        super().__init__(make,model,year)
        self.battery_percent=70
    
    def battery_percents(self):
        print('The battery percent of car is '+str(self.battery_percent)+'-kWh battery.')
    def fill_gas_tank(self):
        print('This car doesn\'t have gas tank!')
        
my_tesla=ElectricCar('Tesla','model s',2016)
my_tesla.fill_gas_tank()

# %%
#Instances as Attributes
class Car():#parent class
    def __init__(self,make,model,year):
        self.make=make
        self.model=model
        self.year=year
        self.odometer_reading=0
        
    def get_descriptive_name(self):
        long_name=str(self.year)+' '+self.make+' '+self.model
        return long_name.title()
    
    def read_odometer(self):
        print('This car has '+str(self.odometer_reading)+' miles on it.')
    
    def update_odometer(self,milage):#new method
        """Set the odometer reading to the given value.
         Reject the change if it attempts to roll the odometer back.
         """
        if milage>=self.odometer_reading:
            self.odometer_reading=milage
        else:
            print('You cannot roll back an odometer!!\n')
            
    def increment_odometer(self,miles):
        self.odometer_reading+=miles
    
class Battery():
    """A simple attempt to model a battery for an electric car."""
    
    def __init__(self,battery_size=70):
        """Initialize the battery's attribite"""
        self.battery_size=battery_size
    
    def describe_battery(self):
        """Print a statement describing the battery size."""
        print('This car has a '+str(self.battery_size)+'-kWh battery')
    
    
class ElectricCar(Car):#child class
    """Represent aspects of a car, specific to electric vehicles."""
    
    def __init__(self,make,model,year):
        """Initialize attributes of the parent class."""
        super().__init__(make,model,year)
        self.battery=Battery()
    
        
my_tesla=ElectricCar('Tesla','model s',2016)
print(my_tesla.get_descriptive_name())
my_tesla.battery.describe_battery()

#Here we created a new class Battery() 
# In ElectricCar class we create a new attribute that called self.battery which is a instance of class Battery
# when we call eletriccar ,__init__() method is trigerred and it creates a instance of class battery.
# my_tesla.battery.describe_battery(),this tell at instance my_tesla look for battery and call describe_battery()

# %%
class Car():#parent class
    def __init__(self,make,model,year):
        self.make=make
        self.model=model
        self.year=year
        self.odometer_reading=0
        
    def get_descriptive_name(self):
        long_name=str(self.year)+' '+self.make+' '+self.model
        return long_name.title()
    
    def read_odometer(self):
        print('This car has '+str(self.odometer_reading)+' miles on it.')
    
    def update_odometer(self,milage):#new method
        """Set the odometer reading to the given value.
         Reject the change if it attempts to roll the odometer back.
         """
        if milage>=self.odometer_reading:
            self.odometer_reading=milage
        else:
            print('You cannot roll back an odometer!!\n')
            
    def increment_odometer(self,miles):
        self.odometer_reading+=miles
    
class Battery():
    """A simple attempt to model a battery for an electric car."""
    
    def __init__(self,battery_size=70):
        """Initialize the battery's attribite"""
        self.battery_size=battery_size
    
    def describe_battery(self):
        """Print a statement describing the battery size."""
        print('This car has a '+str(self.battery_size)+'-kWh battery')
    
    def get_range(self):
        """Print a statement about the range this battery provides."""
        if self.battery_size == 70:
            range=240
        elif self.battery_size == 85:
            range=270
            
        message="This car can go approximately "+str(range)
        message+=" miles on full charge!"
        print(message)
    
class ElectricCar(Car):#child class
    """Represent aspects of a car, specific to electric vehicles."""
    
    def __init__(self,make,model,year):
        """Initialize attributes of the parent class."""
        super().__init__(make,model,year)
        self.battery=Battery()
    
        
my_tesla=ElectricCar('Tesla','model s',2016)
print(my_tesla.get_descriptive_name())
my_tesla.battery.describe_battery()
my_tesla.battery.get_range()

# %%
#9.6 Ice cream stand
class Resturant():
    
    def __init__(self,resturant_name,cuisine_type):
        self.resturant_name=resturant_name
        self.cuisine_type=cuisine_type
        
    def describe_resturant(self):
        print('Our resturant is '+self.resturant_name+' and it\'s famous for '+self.cuisine_type.title()+'.')
    
    def open_resturant(self):
        print(self.resturant_name+' is currently open.')

class IceCreamStand(Resturant):
    
    def __init__(self,resturant_name,cuisine_type='Ice Cream'):
        super().__init__(resturant_name,cuisine_type)
        self.flavors=['chocolate','vanilla','chocolate chips','mango']
    
    def display_flavors(self):
        print('The famous flavors are as follows:')
        for flavor in self.flavors:
            print(flavor)

icecreamstand=IceCreamStand('IceCreamStand')
icecreamstand.describe_resturant()
icecreamstand.display_flavors()

# %%
#9.7 Admin
class User():
    def __init__(self,first_name,last_name,age,address):
        self.first_name=first_name
        self.last_name=last_name
        self.age=age
        self.address=address
        
    def describe_user(self):
        print("\nUser's name is "+self.first_name.title()+" "+self.last_name.title()+". S/he is "+str(self.age)+' years old and lives with family in '+self.address.title()+'.')
    def greet_user(self):
        print('Hello '+self.first_name.title()+'!')

class Admin(User):
    def __init__(self,first_name,last_name,age,address):
        super().__init__(first_name,last_name,age,address)
        self.privilage=['can add post','can delete post','can ban user','can add user']
        
    def show_privilage(self):
        print("Administrator privilages are:")
        for privilages in self.privilage:
            print(privilages)

admin=Admin('Hishan','Shrestha',21,'Teku')
admin.describe_user()
admin.show_privilage()

# %%
#9.8 privilage
class User():
    def __init__(self,first_name,last_name,age,address):
        self.first_name=first_name
        self.last_name=last_name
        self.age=age
        self.address=address
        
    def describe_user(self):
        print("\nUser's name is "+self.first_name.title()+" "+self.last_name.title()+". S/he is "+str(self.age)+' years old and lives with family in '+self.address.title()+'.')
    def greet_user(self):
        print('Hello '+self.first_name.title()+'!')

class Privileges():
    
    def __init__(self):
        self.privileges=['can add post','can delete post','can ban user','can add user']
    
    def show_previleges(self):
        print('Administrator privileges are')
        for privilege in self.privileges:
            print(privilege)
        
        
class Admin(User):
    def __init__(self,first_name,last_name,age,address):
        
        super().__init__(first_name,last_name,age,address)
        self.privileges=Privileges()
        
admin=Admin('Hishan','Shrestha',21,'Teku')
admin.describe_user()
admin.privileges.show_previleges()

# %%
#9.9 Battery Upgrade
class Car():#parent class
    def __init__(self,make,model,year):
        self.make=make
        self.model=model
        self.year=year
        self.odometer_reading=0
        
    def get_descriptive_name(self):
        long_name=str(self.year)+' '+self.make+' '+self.model
        return long_name.title()
    
    def read_odometer(self):
        print('This car has '+str(self.odometer_reading)+' miles on it.')
    
    def update_odometer(self,milage):#new method
        """Set the odometer reading to the given value.
         Reject the change if it attempts to roll the odometer back.
         """
        if milage>=self.odometer_reading:
            self.odometer_reading=milage
        else:
            print('You cannot roll back an odometer!!\n')
            
    def increment_odometer(self,miles):
        self.odometer_reading+=miles
    
class Battery():
    """A simple attempt to model a battery for an electric car."""
    
    def __init__(self,battery_size=70):
        """Initialize the battery's attribite"""
        self.battery_size=battery_size
    
    def describe_battery(self):
        """Print a statement describing the battery size."""
        print('This car has a '+str(self.battery_size)+'-kWh battery')
    
    def get_range(self):
        """Print a statement about the range this battery provides."""
        if self.battery_size == 70:
            range=240
        elif self.battery_size == 85:
            range=270
            
        message="This car can go approximately "+str(range)
        message+=" miles on full charge!"
        print(message)
    
    def upgrade_battery(self):
        if self.battery_size!=85:
            self.battery_size=85
    
class ElectricCar(Car):#child class
    """Represent aspects of a car, specific to electric vehicles."""
    
    def __init__(self,make,model,year):
        """Initialize attributes of the parent class."""
        super().__init__(make,model,year)
        self.battery=Battery()
    
        
my_tesla=ElectricCar('Tesla','model s',2016)
print(my_tesla.get_descriptive_name())
my_tesla.battery.describe_battery()
my_tesla.battery.get_range()
my_tesla.battery.upgrade_battery()
my_tesla.battery.describe_battery()
my_tesla.battery.get_range()

# %% [markdown]
# ### Importing Classes

# %%
#importing single class
#importing from car.py
from cars import Car

my_new_car = Car('audi', 'a4', 2016)
print(my_new_car.get_descriptive_name())
my_new_car.odometer_reading = 23
my_new_car.read_odometer()

# %%
#storing multiple classses in a module
from car import ElectricCar

my_tesla = ElectricCar('tesla', 'model s', 2016)
print(my_tesla.get_descriptive_name())
my_tesla.battery.describe_battery()
my_tesla.battery.get_range()

# %%
#Importing Multiple Classes from a Module
from car import Car, ElectricCar
my_beetle=Car('volkswagen','beetle',2019)
print(my_beetle.get_descriptive_name())

my_tesla=ElectricCar('tesla','roadster',2019)
print(my_tesla.get_descriptive_name())

# %%
#Importing an Entire Module
import car
my_beetle=car.Car('volkswagen','beetle',2019)
print(my_beetle.get_descriptive_name())

my_tesla=car.ElectricCar('tesla','roadster',2019)
print(my_tesla.get_descriptive_name())
# Out:
# 2019 Volkswagen Beetle
# 2019 Tesla Roadster

# %%
#Importing All Classes from a Module
from car import *

# %%
#Importing a Module into a Module
from cars import Car
from electric_car import ElectricCar

my_beetle=car.Car('volkswagen','beetle',2019)
print(my_beetle.get_descriptive_name())

my_tesla=car.ElectricCar('tesla','roadster',2019)
print(my_tesla.get_descriptive_name())

# in electric_car we import Car module
# and here we import both cars and electric_car modules
# Out:
# 2019 Volkswagen Beetle
# 2019 Tesla Roadster

# %% [markdown]
# ## The Python Standard library
#     Python Standard library is a set of modules included with every Python installation
# ### OrderedDict
#     Dictionaries allow u to connect pieces of information,but they dont keep track of the order in which you ass key-value pairs.
#
#     we can user OrderedDict class from collections module to keep track of the order in which key value pairs are added.

# %%
from collections import OrderedDict

favorite_languages= OrderedDict()

favorite_languages['jen']='python'
favorite_languages['sarah']='c'
favorite_languages['edward']='ruby'
favorite_languages['phil']='python'

for name,language in favorite_languages.items():
    print(name.title()+"'s favorite language is "+language.title()+'.')
# Out:
# Jen's favorite language is Python.
# Sarah's favorite language is C.
# Edward's favorite language is Ruby.
# Phil's favorite language is Python.
